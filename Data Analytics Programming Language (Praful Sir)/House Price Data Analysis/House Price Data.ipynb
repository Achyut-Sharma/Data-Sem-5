# %% [markdown]
# # House Price DataSet

# %% [markdown]
# ## Date:- 3 July 23

# %% [raw]
# # About Dataset
# This data set was very useful when I worked on a project .As a Kaggle contributer I am uploading for others to gain knowledge by implementing algorithms.
#
# Attributes:
# 1.Id(int)
# 2.Date(int)
# 3.number of bedrooms(int)
# 4.number of bathrooms(float)-convert it into 'int' ,just to give you some practice!
# 5.living area(int)
# 6.lot area(int)
# 7.water front present(float)-convert it into 'int'
# 8.number of views(int)

# %%
# Import the packages.
import numpy as np
import pandas as pd

# %%
# Load the dataset.
House_Price_Dataset = pd.read_csv("House Price India.csv")

# %%
# Task 1. Show the first 10 datasets.
House_Price_Dataset.head(10)
#head is used to display upward data.
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
# 5  6762813105  42491                   3                 2.50         2600
# 6  6762813157  42491                   5                 3.25         3660
# 7  6762813599  42491                   3                 1.75         2240
# 8  6762813600  42491                   3                 2.50         2390
# 9  6762814461  42491                   4                 2.25         2200
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# ...

# %%
# Task 2 Show the last 10 Rows:-
House_Price_Dataset.tail(10)
## "tail" is a method used to display last data.
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14610  6762828349  42734                   4                 2.75
# 14611  6762828783  42734                   3                 1.75
# 14612  6762828856  42734                   3                 1.00
# 14613  6762829600  42734                   3                 1.00
# 14614  6762829669  42734                   3                 1.75
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 14610         1810      7350               1.0                   0
# 14611         1350      7686               1.0                   0
# ...

# %%
# Task 3 Show the Size if the Data.
House_Price_Dataset.shape
# Out:
# (14620, 23)

# %% [markdown]
# *Important*
#
# `shape` is a method used to calculate size of the data.

# %% [markdown]
# **Inference of Task 3 **
#
# - we have `14620` Observations (Rows).
# - we have `23` Attributes (Columns).

# %% [markdown]
# # 5 July 23
# # Steps to Get Inferance from the data or EDA(Exploratory Data Analysis):-

# %% [markdown]
# ## Step 1:- Data Pre-Processing

# %% [markdown]
# ## Step 2:- EDA

# %% [markdown]
# ## Step 3 :- Draw the Conclusion

# %%
# Step 1: Data Pre-Processing:-

House_Price_Dataset.head(3)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# ...

# %%
## List out all column names 

House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
## Check for  valid null values in dataset
## `isnull` is used to check valid null value (just blank) not invalid null value (jsut filled with anything) 
House_Price_Dataset.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# ** Inference**
# - We dont have any `valid null` values in the data.

# %% [markdown]
# ## Access the Set Of Columns.

# %%
House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
## Access the Home Coordinates
House_Price_Dataset_Home_Coordinates = House_Price_Dataset [['number of bedrooms', 'living area', 'number of bathrooms','condition of the house',  'Area of the house(excluding basement)', 'Area of the basement']]
House_Price_Dataset_Home_Coordinates.head(3)
# Out:
#    number of bedrooms  living area  number of bathrooms  \
# 0                   5         3650                 2.50
# 1                   4         2920                 2.50
# 2                   5         2910                 2.75
#
#    condition of the house  Area of the house(excluding basement)  \
# 0                       5                                   3370
# 1                       5                                   1910
# 2                       3                                   2910
#
#    Area of the basement
# 0                   280
# 1                  1010
# 2                     0

# %%
## Lattitude of house 52.8645
## Longitude of house -114.557

# %%
## Access the area coordinates.

House_Price_Dataset_Area_Coordinates = House_Price_Dataset[['waterfront present',
'Postal Code','Lattitude','Longitude', 'Number of schools nearby','Distance from the airport']]
House_Price_Dataset_Area_Coordinates.head(3)
# Out:
#    waterfront present  Postal Code  Lattitude  Longitude  \
# 0                   0       122003    52.8645   -114.557
# 1                   0       122004    52.8878   -114.470
# 2                   0       122004    52.8852   -114.468
#
#    Number of schools nearby  Distance from the airport
# 0                         2                         58
# 1                         2                         51
# 2                         1                         53

# %%
## Home Modification Coordinates.

House_Price_Dataset.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
House_Price_Dataset_Modification_Coordinates = House_Price_Dataset[['Renovation Year','living_area_renov','lot_area_renov']]
House_Price_Dataset_Modification_Coordinates.head(3)
# Out:
#    Renovation Year  living_area_renov  lot_area_renov
# 0                0               2880            5400
# 1                0               2470            4000
# 2                0               2940            6600

# %%
## Establishment Coordinates.
House_Price_Dataset_Establishment_Coordinates = House_Price_Dataset[['id', 'Date','condition of the house', 'grade of the house','Built Year','number of views','Price']]
House_Price_Dataset_Establishment_Coordinates.head()
# Out:
#            id   Date  condition of the house  grade of the house  Built Year  \
# 0  6762810145  42491                       5                  10        1921
# 1  6762810635  42491                       5                   8        1909
# 2  6762810998  42491                       3                   8        1939
# 3  6762812605  42491                       3                   9        2001
# 4  6762812919  42491                       4                   8        1929
#
#    number of views    Price
# 0                4  2380000
# 1                0  1400000
# 2                0  1200000
# 3                0   838000
# 4                0   805000

# %% [markdown]
# ## Univariate Analysis to authenticate the data :-
# #  ` Univariate Analysis` shows how the data variates.
# # Means one variable (column) is taken ata atime for analysis is called Univaraite Analysis.

# %% [markdown]
# ## A. Home Corodinates

# %%
House_Price_Dataset_Home_Coordinates.head(3)
# Out:
#    number of bedrooms  living area  number of bathrooms  \
# 0                   5         3650                 2.50
# 1                   4         2920                 2.50
# 2                   5         2910                 2.75
#
#    condition of the house  Area of the house(excluding basement)  \
# 0                       5                                   3370
# 1                       5                                   1910
# 2                       3                                   2910
#
#    Area of the basement
# 0                   280
# 1                  1010
# 2                     0

# %%
House_Price_Dataset_Home_Coordinates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 6 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   number of bedrooms                     14620 non-null  int64
#  1   living area                            14620 non-null  int64
#  2   number of bathrooms                    14620 non-null  float64
#  3   condition of the house                 14620 non-null  int64
#  4   Area of the house(excluding basement)  14620 non-null  int64
#  5   Area of the basement                   14620 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 685.4 KB

# %% [markdown]
# ### `info()` shows the information about the data.

# %% [markdown]
# ### ` describe()` is used to claculate the statistics of the data

# %% [markdown]
#  **Inference**
# - In this home coordinate dataset we have all Columns Numerical in nature.
# - In the same 2 columns as Float and reamining 6 are integer

# %%
House_Price_Dataset_Home_Coordinates.describe()
# Out:
#        number of bedrooms   living area  number of bathrooms  \
# count        14620.000000  14620.000000         14620.000000
# mean             3.379343   2098.262996             2.129583
# std              0.938719    928.275721             0.769934
# min              1.000000    370.000000             0.500000
# 25%              3.000000   1440.000000             1.750000
# 50%              3.000000   1930.000000             2.250000
# 75%              4.000000   2570.000000             2.500000
# max             33.000000  13540.000000             8.000000
#
#        condition of the house  Area of the house(excluding basement)  \
# count            14620.000000                           14620.000000
# mean                 3.430506                            1801.783926
# std                  0.664151                             833.809963
# min                  1.000000                             370.000000
# ...

# %%
House_Price_Dataset_Home_Coordinates.describe().T
# Out:
#                                          count         mean         std  \
# number of bedrooms                     14620.0     3.379343    0.938719
# living area                            14620.0  2098.262996  928.275721
# number of bathrooms                    14620.0     2.129583    0.769934
# condition of the house                 14620.0     3.430506    0.664151
# Area of the house(excluding basement)  14620.0  1801.783926  833.809963
# Area of the basement                   14620.0   296.479070  448.551409
#
#                                          min      25%      50%     75%  \
# number of bedrooms                       1.0     3.00     3.00     4.0
# living area                            370.0  1440.00  1930.00  2570.0
# number of bathrooms                      0.5     1.75     2.25     2.5
# condition of the house                   1.0     3.00     3.00     4.0
# Area of the house(excluding basement)  370.0  1200.00  1580.00  2240.0
# ...

# %%
## Now the time is to visualize the existing home coordinate  
# Import Seaborn library
import seaborn as sns


#Import Matplotlib library
import matplotlib.pyplot as plt

# %%
#Draw the pairplot
sns.pairplot(House_Price_Dataset_Home_Coordinates)
plt.show()

# %% [markdown]
# ### pairplot plots all the combinations of numeric columns from a dataset.
# ###  Here all attributes present in Home_Coordinates such as(no.of bedrroms,living area,no.of bathrooms etc) are plotted as
# ### combination by `pairplot.`

# %%
#Draw the pairplot
sns.pairplot(House_Price_Dataset_Home_Coordinates,kind="hist")
plt.show()

# %% [markdown]
# **Interepretation**
# - Living Area Vs Area Of House Excluding Basement.
# - Area Of House Excluding Basement Vs no.of bathrooms.
# - Living Area Vs No. Of Bathroom.
# - No. of bedrooms Vs Living Area having gradual growth
# - No.Of bathrooms Vs Condition of house/No.of FLoors (No Realtion).
# - Living area vs Area of house having hetro scadasticity.
